# %%
import pandas as pd                        
from pytrends.request import TrendReq
pd.options.display.max_rows = 250

# %%
pytrend = TrendReq()

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
kw_list=["coronavirus", "face mask"]

# %%
pytrend.build_payload(kw_list, timeframe = 'today 3-m', geo="US")

# %%
pytrend.interest_over_time()
# Out:
#             coronavirus  face mask  isPartial
# date
# 2020-01-07            0          0      False
# 2020-01-08            0          0      False
# 2020-01-09            0          0      False
# 2020-01-10            0          0      False
# 2020-01-11            0          0      False
# 2020-01-12            0          0      False
# 2020-01-13            0          0      False
# 2020-01-14            0          0      False
# 2020-01-15            0          0      False
# 2020-01-16            0          0      False
# 2020-01-17            0          0      False
# 2020-01-18            0          0      False
# 2020-01-19            0          0      False
# 2020-01-20            0          0      False
# 2020-01-21            3          0      False
# 2020-01-22            3          0      False
# 2020-01-23            4          0      False
# 2020-01-24            8          0      False
# 2020-01-25            8          0      False
# ...

# %%
df = pytrend.interest_by_region()
sorted = df.sort_values(kw_list, ascending=False)
sorted.head(55)
# Out:
#                       coronavirus  face mask
# geoName
# Alabama                        99          1
# Arizona                        99          1
# Florida                        99          1
# Idaho                          99          1
# Indiana                        99          1
# Iowa                           99          1
# Maine                          99          1
# Minnesota                      99          1
# Montana                        99          1
# New Mexico                     99          1
# North Carolina                 99          1
# North Dakota                   99          1
# Ohio                           99          1
# South Carolina                 99          1
# South Dakota                   99          1
# Tennessee                      99          1
# Utah                           99          1
# West Virginia                  99          1
# Wisconsin                      99          1
# Wyoming                        99          1
# ...

# %%
#CSV for global confirmed cases. Will filter out US and sum.
pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_confirmed.csv', delimiter=',')
# Out:
#                         Province/State                Country       Lat  \
# 0                                  NaN            Afghanistan  33.00000
# 1                                  NaN                Albania  41.15330
# 2                                  NaN                Algeria  28.03390
# 3                                  NaN                Andorra  42.50630
# 4                                  NaN                 Angola -11.20270
# ..                                 ...                    ...       ...
# 258  Falkland Islands (Islas Malvinas)         United Kingdom -51.79630
# 259          Saint Pierre and Miquelon                 France  46.88520
# 260                                NaN            South Sudan   6.87700
# 261                                NaN         Western Sahara  24.21550
# 262                                NaN  Sao Tome and Principe   0.18636
#
#           Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
confirmed = pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_confirmed.csv', delimiter=',')

# %%
confirmed.loc[confirmed['Country'] == 'US']
# Out:
#     Province/State Country      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 225            NaN      US  37.0902 -95.7129        1        1        2
#
#      1/25/20  1/26/20  1/27/20  ...  3/28/20  3/29/20  3/30/20  3/31/20  \
# 225        2        5        5  ...   121478   140886   161807   188172
#
#      4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20
# 225  213372  243453  275586  308850  337072  366614
#
# [1 rows x 80 columns]

# %%
df = confirmed.loc[confirmed['Country'] == 'US']

# %%
df.to_csv('~/Desktop/Data/pandas-project/output/us_confirmed.csv', index = False)

# %%
# sum of confirmed in the US as of April 6 = 2831915

# %%
# couldn't figure out how to sum certain columns in row

# %%
us_confirmed = 2831915

# %%
print(us_confirmed)
# Out:
# 2831915

# %%
#CSV for global deaths. Will filter out US and sum.

# %%
pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_deaths.csv', delimiter=',')
# Out:
#                         Province/State                Country       Lat  \
# 0                                  NaN            Afghanistan  33.00000
# 1                                  NaN                Albania  41.15330
# 2                                  NaN                Algeria  28.03390
# 3                                  NaN                Andorra  42.50630
# 4                                  NaN                 Angola -11.20270
# ..                                 ...                    ...       ...
# 258  Falkland Islands (Islas Malvinas)         United Kingdom -51.79630
# 259          Saint Pierre and Miquelon                 France  46.88520
# 260                                NaN            South Sudan   6.87700
# 261                                NaN         Western Sahara  24.21550
# 262                                NaN  Sao Tome and Principe   0.18636
#
#           Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  \
# ...

# %%
deaths = pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_deaths.csv', delimiter=',')

# %%
deaths.loc[deaths['Country'] == 'US']
# Out:
#     Province/State Country      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 225            NaN      US  37.0902 -95.7129        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  3/28/20  3/29/20  3/30/20  3/31/20  \
# 225        0        0        0  ...     2026     2467     2978     3873
#
#      4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20
# 225    4757    5926    7087    8407    9619   10783
#
# [1 rows x 80 columns]

# %%
df=deaths.loc[deaths['Country'] == 'US']

# %%
us_deaths = 64777

# %%
#export row to Output folder
df.to_csv('~/Desktop/Data/pandas-project/output/us_deaths.csv', index=False)

# %%
#CSV for global recovered cases. Will filter out US and sum.

# %%
pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_recovered.csv', delimiter=',').head(5)
# Out:
#   Province/State      Country      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN  Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN      Albania  41.1533  20.1683        0        0        0
# 2            NaN      Algeria  28.0339   1.6596        0        0        0
# 3            NaN      Andorra  42.5063   1.5218        0        0        0
# 4            NaN       Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  \
# 0        0        0        0  ...        2        2        2        5       5
# 1        0        0        0  ...       31       33       44       52      67
# 2        0        0        0  ...       31       31       37       46      61
# 3        0        0        0  ...        1        1       10       10      10
# 4        0        0        0  ...        0        0        0        1       1
#
#    4/2/20  4/3/20  4/4/20  4/5/20  4/6/20
# ...

# %%
recovered = pd.read_csv('~/Desktop/Data/pandas-project/notebooks/global_recovered.csv', delimiter=',')

# %%
recovered.loc[recovered['Country'] == 'US']
# Out:
#     Province/State Country      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 225            NaN      US  37.0902 -95.7129        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  3/28/20  3/29/20  3/30/20  3/31/20  \
# 225        0        0        0  ...     1072     2665     5644     7024
#
#      4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20
# 225    8474    9001    9707   14652   17448   19581
#
# [1 rows x 80 columns]

# %%
df= recovered.loc[recovered['Country'] == 'US']

# %%
df.to_csv('~/Desktop/Data/pandas-project/output/us_recovered.csv', index = False)

# %%
us_recovered = 98681

# %%
print("Total US Confirmed: ", us_confirmed)
print("Total US Deaths: ", us_deaths)
print("Total US Recovered: ", us_recovered)
# Out:
# Total US Confirmed:  2831915
# Total US Deaths:  64777
# Total US Recovered:  98681
