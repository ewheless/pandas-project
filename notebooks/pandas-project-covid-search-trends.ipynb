# %%
import pandas as pd                        
from pytrends.request import TrendReq
pd.options.display.max_rows = 250

# %%
pytrend = TrendReq()

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
kw_list=["coronavirus", "face mask"]

# %%
pytrend.build_payload(kw_list, timeframe = 'today 3-m', geo="US")

# %%
pytrend.interest_over_time()
# Out:
#             coronavirus  face mask  isPartial
# date
# 2020-01-07            0          0      False
# 2020-01-08            0          0      False
# 2020-01-09            0          0      False
# 2020-01-10            0          0      False
# 2020-01-11            0          0      False
# 2020-01-12            0          0      False
# 2020-01-13            0          0      False
# 2020-01-14            0          0      False
# 2020-01-15            0          0      False
# 2020-01-16            0          0      False
# 2020-01-17            0          0      False
# 2020-01-18            0          0      False
# 2020-01-19            0          0      False
# 2020-01-20            0          0      False
# 2020-01-21            3          0      False
# 2020-01-22            3          0      False
# 2020-01-23            4          0      False
# 2020-01-24            8          0      False
# 2020-01-25            8          0      False
# 2020-01-26           10          0      False
# 2020-01-27           11          0      False
# 2020-01-28           12          0      False
# 2020-01-29           11          0      False
# 2020-01-30           11          0      False
# 2020-01-31           11          0      False
# 2020-02-01            9          0      False
# 2020-02-02            8          0      False
# 2020-02-03            7          0      False
# 2020-02-04            6          0      False
# 2020-02-05            5          0      False
# 2020-02-06            6          0      False
# 2020-02-07            6          0      False
# 2020-02-08            6          0      False
# 2020-02-09            5          0      False
# 2020-02-10            5          0      False
# 2020-02-11            5          0      False
# 2020-02-12            4          0      False
# 2020-02-13            5          0      False
# 2020-02-14            4          0      False
# 2020-02-15            4          0      False
# 2020-02-16            3          0      False
# 2020-02-17            4          0      False
# 2020-02-18            4          0      False
# 2020-02-19            3          0      False
# 2020-02-20            3          0      False
# 2020-02-21            3          0      False
# 2020-02-22            4          0      False
# 2020-02-23            5          0      False
# 2020-02-24            7          0      False
# 2020-02-25           10          0      False
# 2020-02-26           16          1      False
# 2020-02-27           18          1      False
# 2020-02-28           18          1      False
# 2020-02-29           19          1      False
# 2020-03-01           17          1      False
# 2020-03-02           25          1      False
# 2020-03-03           25          0      False
# 2020-03-04           23          0      False
# 2020-03-05           28          0      False
# 2020-03-06           30          0      False
# 2020-03-07           30          0      False
# 2020-03-08           29          0      False
# 2020-03-09           37          0      False
# 2020-03-10           44          0      False
# 2020-03-11           55          0      False
# 2020-03-12           95          1      False
# 2020-03-13           87          1      False
# 2020-03-14           78          1      False
# 2020-03-15          100          1      False
# 2020-03-16           95          0      False
# 2020-03-17           86          0      False
# 2020-03-18           78          0      False
# 2020-03-19           76          1      False
# 2020-03-20           73          1      False
# 2020-03-21           73          1      False
# 2020-03-22           74          1      False
# 2020-03-23           70          1      False
# 2020-03-24           63          1      False
# 2020-03-25           60          1      False
# 2020-03-26           58          1      False
# 2020-03-27           58          1      False
# 2020-03-28           55          1      False
# 2020-03-29           54          1      False
# 2020-03-30           50          1      False
# 2020-03-31           47          1      False
# 2020-04-01           47          2      False
# 2020-04-02           45          3      False
# 2020-04-03           55          5      False
# 2020-04-04           59          7      False

# %%
df = pytrend.interest_by_region()
sorted = df.sort_values(kw_list, ascending=False)
sorted.head(55)
# Out:
#                       coronavirus  face mask
# geoName
# Alabama                        99          1
# Arizona                        99          1
# Florida                        99          1
# Idaho                          99          1
# Indiana                        99          1
# Iowa                           99          1
# Maine                          99          1
# Minnesota                      99          1
# Montana                        99          1
# New Mexico                     99          1
# North Carolina                 99          1
# North Dakota                   99          1
# Ohio                           99          1
# South Carolina                 99          1
# South Dakota                   99          1
# Tennessee                      99          1
# Utah                           99          1
# West Virginia                  99          1
# Wisconsin                      99          1
# Wyoming                        99          1
# Alaska                         98          2
# Arkansas                       98          2
# California                     98          2
# Colorado                       98          2
# Connecticut                    98          2
# Delaware                       98          2
# District of Columbia           98          2
# Georgia                        98          2
# Illinois                       98          2
# Kansas                         98          2
# Kentucky                       98          2
# Louisiana                      98          2
# Maryland                       98          2
# Massachusetts                  98          2
# Michigan                       98          2
# Mississippi                    98          2
# Missouri                       98          2
# Nebraska                       98          2
# Nevada                         98          2
# New Hampshire                  98          2
# New Jersey                     98          2
# New York                       98          2
# Oklahoma                       98          2
# Oregon                         98          2
# Pennsylvania                   98          2
# Rhode Island                   98          2
# Texas                          98          2
# Vermont                        98          2
# Virginia                       98          2
# Washington                     98          2
# Hawaii                         96          4

# %%
pd.read_csv("../data/time_series_covid19_confirmed_global to 4/6.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-115-dedf066d99e2> in <module>
# ----> 1 pd.read_csv("../data/time_series_covid19_confirmed_global to 4/6.csv")
#
# ~/.local/share/virtualenvs/pandas-project-sHzUfUBa/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/.local/share/virtualenvs/pandas-project-sHzUfUBa/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/.local/share/virtualenvs/pandas-project-sHzUfUBa/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/.local/share/virtualenvs/pandas-project-sHzUfUBa/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/.local/share/virtualenvs/pandas-project-sHzUfUBa/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../data/time_series_covid19_confirmed_global to 4/6.csv does not exist: '../data/time_series_covid19_confirmed_global to 4/6.csv'
